# %% [markdown]
# # Welcome to Your First Notebook
#
# This is a sample Jupyter Notebook that will become a page on your website. You can mix Markdown, code, and LaTeX.

# %% [markdown]
# ## Code Cells
#
# Code cells will be executed, and their output will be displayed on the website.

# %%
import random

x = random.randint(1, 100)
print(f"Here is a random number: {x}")

# %% [markdown]
# ## LaTeX Support
#
# You can write inline LaTeX, like Einstein's famous equation: $E = mc^2$.
#
# You can also write display-mode equations, which will be centered on their own line:
#
# $$ \frac{1}{n} \sum_{i=1}^{n} x_i $$

# %% [markdown]
# ## Citations with BibTeX
#
# You can easily add citations from your `.bib` file. For example, here is a citation to a famous paper by Einstein {cite}`einstein1905`.
#
# Jupyter Book will automatically format this and add a bibliography at the bottom of the page.
#
# This is the actual directive that will build your references:
#
# ```{bibliography} _bibliography.bib
# ```
